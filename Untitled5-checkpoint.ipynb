# %%
import os
import numpy as np
import random
import sys  
import time

V=60 #vehicule pace
H=0  #time travel
fichier = open("data.txt", "r")
line=fichier.readline()

fin=line.index(" ")
num_starts=int(line[0:fin])   # number of start-offices
line=line[fin+1:]

fin=line.index(" ")
num_ends=int(line[0:fin])   # number of end-offices
line=line[fin+1:]

fin=line.index(" ")
num_bus_station=int(line[0:fin])   # number of bus-stops (intermediate nodes)
line=line[fin+1:]
print (f"total numbre of stations is : {num_starts+num_ends+num_bus_station}")
nb_vehicle=int(line)          # number of vehicles

#Travel distances reading
distances = np.empty((0, num_starts+num_bus_station+num_ends),int)
line=fichier.readline()
starts=[]
for i in range (num_starts) :
    starts=[]
    for j in range (num_starts):
        starts.append(0)  
    for j in range (num_bus_station):
        fin=line.index(" ")
        x = int(line[0:fin])
        line=line[fin+1:]
        starts.append(x)
    for j in range (num_ends):
        starts.append(0)
    new_row = np.array(starts).reshape(1, num_starts+num_bus_station+num_ends)
    distances=np.append(distances, new_row, axis=0)
for i in range (num_bus_station):
    starts=[]
    for j in range (num_starts):
        starts.append(0)
    for j in range (num_bus_station):
        if j != i:
            fin=line.index(" ")
            x = int(line[0:fin])
            line=line[fin+1:]
            starts.append(x)
        else :
            starts.append(0)
    for j in range (num_ends):
        starts.append(0)
    new_row = np.array(starts).reshape(1, num_starts+num_bus_station+num_ends)
    distances=np.append(distances, new_row, axis=0)
for i in range(num_starts,num_bus_station+num_starts):
    for j in range(num_starts+num_bus_station,num_bus_station+num_starts+num_ends):
        fin=line.index(" ")
        x = int(line[0:fin])
        line=line[fin+1:]
        distances[i,j]=x
print(f"distances = \n {distances}")
#Number of vehicles assigned to start-offices reading
Vdepot=[]
line=fichier.readline()
tot=0
for i in range(num_starts):
    fin=line.index(" ")
    x = int(line[0:fin])
    line=line[fin+1:]
    Vdepot.append(x)
    tot = tot + x

#Vehicles capacities reading
v_cap=[]
line=fichier.readline()
totcap=0
for i in range(nb_vehicle):
    fin=line.index(" ")
    x = int(line[0:fin])
    line=line[fin+1:]
    v_cap.append(x)
    totcap=totcap+x

#Waiting persons Number reading
Ncustemers=[]
line=fichier.readline()
tot=0
for i in range(num_starts):
    fin=line.index(" ")
    x = int(line[0:fin])
    line=line[fin+1:]
    Ncustemers.append(x)
    tot=tot+x
for i in range(num_bus_station):
    fin=line.index(" ")
    x = int(line[0:fin])
    line=line[fin+1:]
    Ncustemers.append(x)
    tot=tot+x
N=tot
print (f"total waiting custmurs is :{N}")
print(f"les client:{Ncustemers}")
#Time window
TWs=[]
TWb=[]
TWe=[]
line=fichier.readline()
for i in range(num_starts):
    fin=line.index(" ")
    x = int(line[0:fin])
    line=line[fin+1:]
    TWs.append(x)
for i in range(num_bus_station):
    fin=line.index(" ")
    x = int(line[0:fin])
    line=line[fin+1:]
    TWb.append(x)
for i in range(num_ends):
    fin=line.index(" ")
    x = int(line[0:fin])
    line=line[fin+1:]
    TWe.append(x)
print (f"tws={TWs} twb = {TWb} twe = {TWe}")
# finding nearest intermediate station
def find_nearest_station(current_station, visited_satation):
    remaining_station = np.setdiff1d(range(num_starts,num_bus_station+num_starts), visited_satation)
    if len(remaining_station)==0:
        return -1
    else:
        distances_to_remaining_station = distances[current_station, remaining_station]
        nearest_station = np.argmin(distances_to_remaining_station)
        return remaining_station[nearest_station]
        
# finding nearest ends station
def find_nearest_ends(current_station, visited_station):
    remaining_end_station=np.setdiff1d(range(num_bus_station+num_starts,num_bus_station+num_starts+num_ends),visited_station)
    distances_to_ends = distances[current_station,remaining_end_station]
    nearest_station = np.argmin(distances_to_ends)
    return  remaining_end_station[nearest_station]

# finding nearest first and unique intermediate station
def find_nearest_firsts(current_station):
    route = [current_station]
    remaining_end_station=range(num_starts,num_bus_station+num_starts)
    distances_to_ends = distances[current_station,remaining_end_station]
    nearest_station = np.argmin(distances_to_ends)
    return  remaining_end_station[nearest_station]

# function for resolution of VRP multiple starts/ends with Nearest Neighbors(NN)
def solve_vrp_nn(start_depot,cap):
    global visited_station
    visited_station = []
    current_station = start_depot
    route = [current_station]
    global N
    global H

    while len(visited_station) < num_bus_station and cap > 0:
        nearest_station = find_nearest_station(current_station, visited_station)
        while len(visited_station) < num_bus_station and Ncustemers[nearest_station]==0:
            visited_station.append(nearest_station)
            nearest_station = find_nearest_station(current_station, visited_station)
        if nearest_station==-1:
            if current_station == start_depot and cap<30:
                nearest_station=find_nearest_firsts(current_station)
                dure=(distances[current_station, nearest_station])/V
                H=H+dure
            else:
                if current_station == start_depot:
                    return route
        if nearest_station!=-1:
            visited_station.append(nearest_station)
            dure=(distances[current_station, nearest_station])/V
            H1=H+dure
            if H1<TWb[nearest_station-num_starts]:
                route.append(nearest_station)
                H=H1
                if Ncustemers[nearest_station]<cap:
                    cap = cap - Ncustemers[nearest_station]
                    N=N-Ncustemers[nearest_station]
                    upCust.append(Ncustemers[nearest_station])
                    Ncustemers[nearest_station]=0
                else :
                    upCust.append(cap)
                    Ncustemers[nearest_station]=Ncustemers[nearest_station]-cap
                    N=N-cap
                    cap=0
                current_station = nearest_station
    k=num_ends    
    while k > 0 :
        nearest_end=find_nearest_ends(current_station, visited_station)
        dure=(distances[current_station, nearest_end])/V
        H1=H+dure
        if H1<TWe[nearest_end-(num_starts+num_bus_station)]:
            route.append(nearest_end)
            H=H1
            return route
        visited_station.append(nearest_end)
        k=k-1
    return route

# function for resolution of VRP multiple starts/ends from start to end passing by one intermediate station
def solve_vrp_start_end():
    global N
    global cap
    visited_station = []
    current_station=start_depot
    upCust.append(cap)
    Ncustemers[i]=Ncustemers[i]-cap
    N=N-cap
    cap=0
    route.append(current_station)
    current_station=find_nearest_firsts(current_station)
    route.append(current_station)
    route.append(find_nearest_ends(current_station, visited_station))
totD=0
start_time = time.time()
# Resolution of our VRP multiple starts/ends with Nearest Neighbors (NN) from each Starting station
for i in range(num_starts):
    start_depot = i
    for j in range(Vdepot[i]):
        if N!=0:
            H=TWs[start_depot]
            cap=v_cap[i]
            d=0
            upCust=[]
            route=[]
            if Ncustemers[i]<v_cap[i]:
                cap=cap-Ncustemers[i]
                upCust.append(Ncustemers[i])
                N=N-Ncustemers[i]
                Ncustemers[i]=0
                route = solve_vrp_nn(start_depot,cap)
            else :
                solve_vrp_start_end()
            print(f"Route starting from Starting Station {start_depot} by the vehicle {j} : {route}")
            print(f"Time of travel is :{H}")
            print(f"Number of custumers taken from each station : {upCust}")
            for k in range(len(route)-1):
                d=d+distances[route[k],route[k+1]]
            print(f"Distance traveled is :{d}")
            totD=totD+d

end_time = time.time()
execution_time = end_time - start_time
print("Time of execution is ", execution_time, "secondes.")
if N==0:
    print("All the custumers have been taken")
else:
    print(f"The number of vehicle is note enough it remain {N} custmuers")
print(f"The total distance traveled by all the vehicles is :{totD}")
# Out:
# total numbre of stations is : 14
# distances =
#  [[  0   0   0  79   3  47  39  66  13  54   9  42   0   0]
#  [  0   0   0  23  75  27  39  92  23   7  22  31   0   0]
#  [  0   0   0  67  30  33  76  22  88  13  60  34   0   0]
#  [  0   0   0   0   4  25  37  23  27  34  72  90  68  60]
#  [  0   0   0  28   0  17  51  68  57  51  81  21  90  64]
#  [  0   0   0  57  13   0  32  68  23  54  71  71  61  36]
#  [  0   0   0  65  44  78   0  15  48  85  63  13  71   1]
#  [  0   0   0  93  94  13  11   0  84  90  34  58  59  81]
#  [  0   0   0  35  53  50  54  92   0  14  70  61  45   4]
#  [  0   0   0  55  43  32  94  71  48   0   9  42  71  53]
#  [  0   0   0  60  36  90 100  24  58  50   0  61  94  74]
#  [  0   0   0  70 100  21  30  55  23  60  88   0  29  28]]
# total waiting custmurs is :178
# les client:[26, 17, 23, 13, 12, 12, 13, 13, 12, 12, 12, 13]
# tws=[5, 6, 6] twb = [7, 7, 8, 8, 8, 9, 9, 8, 7] twe = [9, 9]
# Route starting from Starting Station 0 by the vehicle 0 : [0, 4, 13]
# Time of travel is :6.116666666666666
# Number of custumers taken from each station : [26, 4]
# Distance traveled is :67
# Route starting from Starting Station 0 by the vehicle 1 : [0, 4, 5, 8, 13]
# Time of travel is :5.783333333333333
# Number of custumers taken from each station : [0, 8, 12, 10]
# Distance traveled is :47
# Route starting from Starting Station 1 by the vehicle 0 : [1, 9, 10, 13]
# Time of travel is :7.5
# Number of custumers taken from each station : [17, 12, 1]
# Distance traveled is :90
# Route starting from Starting Station 1 by the vehicle 1 : [1, 10, 7, 6, 13]
# Time of travel is :6.966666666666667
# Number of custumers taken from each station : [0, 11, 13, 6]
# Distance traveled is :58
# Route starting from Starting Station 2 by the vehicle 0 : [2, 11, 13]
# Time of travel is :7.033333333333333
# Number of custumers taken from each station : [23, 7]
# Distance traveled is :62
# Route starting from Starting Station 2 by the vehicle 1 : [2, 11, 8, 6, 13]
# Time of travel is :7.866666666666667
# Number of custumers taken from each station : [0, 6, 2, 7]
# Distance traveled is :112
# Time of execution is  0.004022836685180664 secondes.
# The number of vehicle is note enough it remain 13 custmuers
# The total distance traveled by all the vehicles is :436
