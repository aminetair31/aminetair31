# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
plt.plot([1,3,4,5,6],[1,4,9,7,8])
plt.show()

# %%
df = pd.read_excel('test1 cp nn.xlsx',nrows=20)
df1= pd.read_excel('teste1 avec TW (1).xlsx',nrows=9)
df2= pd.read_excel('KNN.xlsx',nrows=15)
df3= pd.read_excel('KNN vs NN.xlsx',nrows=16)

# %%
Graph_size=df['Graph size']
#print(Graph_size)
cp_dist=df['cp_distance']
#print(cp_dist)
nn_dist=df['nn_distance']
#print(nn_dist)
plt.plot(Graph_size,cp_dist,"r--",label="cplex")
plt.plot(Graph_size,nn_dist,"b:o",label="nn")
plt.legend()
plt.title('cplex  vs NN in distances')
plt.show()

# %%
Graph_size=df1['Graph size']
#print(Graph_size)
cp_dist=df1['cp_distance']
#print(cp_dist)
nn_dist=df1['nn_distance']
#print(nn_dist)
plt.plot(Graph_size,cp_dist,"r--",label="cplexTW")
plt.plot(Graph_size,nn_dist,"b:o",label="nnTW")
plt.legend()
plt.title('cplex TW vs NN TW in distances')
plt.show()

# %%
Graph_size=df2['Graph size']
#print(Graph_size)
cp_dist=df2['cp_distance']
#print(cp_dist)
nn_dist=df2['knn_distance']
#print(nn_dist)
plt.plot(Graph_size,cp_dist,"r--",label="cplexTW")
plt.plot(Graph_size,nn_dist,"b:o",label="knnTW")
plt.legend()
plt.title('cplex TW vs KNN TW in distance')
plt.show()

# %%
Graph_size=df3['Graph size']
#print(Graph_size)
nn_dist=df3['nn_distance']
#print(cp_dist)
knn_dist=df3['knn_distance']
#print(nn_dist)
plt.plot(Graph_size,nn_dist,"r--",label="nnTW")
plt.plot(Graph_size,knn_dist,"b:o",label="knnTW")
plt.legend()
plt.title('KNN TW vs NN TW in distance')
plt.show()

# %%
Graph_size=df['Graph size']
#print(Graph_size)
cp_time=df['cp_exe_Time']
#print(cp_dist)
nn_time=df['nn_exe_Time ']
#print(nn_dist)
plt.plot(Graph_size,cp_time,"r--",label="cplex")
plt.plot(Graph_size,nn_time,"b:o",label="nn")
plt.legend()
plt.title('cplex  vs NN in time ')
plt.show()

# %%
Graph_size1=df1['Graph size']
#print(Graph_size)
cp_time1=df1['cp_exe_Time']
#print(cp_dist)
nn_time1=df1['nn_exe_Time ']
#print(nn_dist)
plt.plot(Graph_size1,cp_time1,"r--",label="cplexTW")
plt.plot(Graph_size1,nn_time1,"b:o",label="nnTW")
plt.legend()
plt.title('cplex TW vs NN TW in time')
plt.show()

# %%
Graph_size2=df2['Graph size']
#print(Graph_size)
cp_time2=df2['cp_exe_Time']
#print(cp_dist)
knn_time2=df2['knn_exe_Time ']
#print(nn_dist)
plt.plot(Graph_size2,cp_time2,"r--",label="cplexTW")
plt.plot(Graph_size2,knn_time2,"b:o",label="knnTW")
plt.legend()
plt.title('cplex TW vs KNN TW in time')
plt.show()

# %%
Graph_size3=df3['Graph size']
#print(Graph_size)
nn_time3=df3['nn_exe_Time']
#print(cp_dist)
knn_time3=df3['knn_exe_Time ']
#print(nn_dist)
plt.plot(Graph_size3,nn_time3,"r--",label="nnTW")
plt.plot(Graph_size3,knn_time3,"b:o",label="knnTW")
plt.legend()
plt.title('KNN TW vs NN TW in time')
plt.show()

# %%
dist_gap=df['distance_gap']
dist_gap1=df1['distance_gap']
dist_gap2=df2['distance_gap']
dist_gap3=df3['distance_gap']
Graph_size3=df3['Graph size']
Graph_size2=df2['Graph size']
Graph_size1=df1['Graph size']
Graph_size=df['Graph size']
plt.plot(Graph_size,dist_gap,"r--",label="nn cp")
plt.legend()
plt.title('distance gap entre nn et cplex')
plt.show()
plt.plot(Graph_size1,dist_gap1,"g-",label="nn cp tw")
plt.legend()
plt.title('distance gap entre nn TW et cplex TW')
plt.show()
plt.plot(Graph_size2,dist_gap2,"b:o",label="knn cp tw")
plt.legend()
plt.title('distance gap entre knn TW et cplex TW')
plt.show()
plt.plot(Graph_size3,dist_gap3,label="knn nn tw")
plt.legend()
plt.title('distance gap entre knn TW et nn TW')
plt.show()

# %%
gf = pd.read_excel('ensemble.xlsx',nrows=8)
gp = pd.read_excel('nnKNN.xlsx',nrows=22)

# %%
Graph_size=gf['graph_size']
nn_dist=gf['nn_dist']
nnTW_dist=gf['nnTW_dist']
knn_dist=gf['knn_dist']
knnTW_dist=gf['knnTW_dist']
cp_dist=gf['cp_dist']
Graph_size1=gp['Graph size']
nn_distance=gp['nn_distance']
knn_distance=gp['knn_distance']
dist_gap=gp['dist_gap']

# %%
plt.plot(Graph_size,nn_dist,"r--",label="nn")
plt.plot(Graph_size,knn_dist,"g:o",label="knn")
plt.plot(Graph_size,nnTW_dist,"b:o",label="nnTW")
plt.plot(Graph_size,knnTW_dist,"b--",label="knnTW")
plt.plot(Graph_size,cp_dist,"g--",label="cp")
plt.legend()
plt.title('NN vs KNN vs NN TW vs KNN TW vs CP')
plt.show()

# %%
plt.plot(Graph_size1,nn_distance,"r:o",label="nn")
plt.plot(Graph_size1,knn_distance,"g:o",label="knn")
plt.legend()
plt.title('NN vs KNN ')
plt.show()

# %%
plt.plot(Graph_size1,dist_gap,"g:o",label="gap")
plt.legend()
plt.title('gap distance betwin NN & KNN ')
plt.show()

# %%
nn_time=gp['nn_time']
knn_time=gp['knn_time']
plt.plot(Graph_size1,nn_time,"g:o",label="nn_time")
plt.plot(Graph_size1,knn_time,"b:o",label="knn_time")
plt.legend()
plt.title('NN vs KNN time')
plt.show()
